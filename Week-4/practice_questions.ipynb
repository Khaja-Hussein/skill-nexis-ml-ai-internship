# %% [markdown]
# # Week 4 - Practice Questions
#
# ## Model Evaluation & Optimization

# %% [markdown]
# ### Question 1: Use cross_val_score to Test Accuracy

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
iris = load_iris()

X = iris.data
y = iris.target

model = LogisticRegression(max_iter=1000)

scores = cross_val_score(model, X, y, cv=5)

print("Cross-validation scores:")
print(scores)

print("Mean accuracy:", scores.mean())
# Out:
# Cross-validation scores:
# [0.96666667 1.         0.93333333 0.96666667 1.        ]
# Mean accuracy: 0.9733333333333334

# %% [markdown]
# ### Question 2: Implement GridSearchCV for SVM

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
svm = SVC()

param_grid = {
    "C": [0.1, 1, 10],
    "kernel": ["linear", "rbf"],
    "gamma": ["scale", "auto"]
}

grid_search = GridSearchCV(
    svm,
    param_grid,
    cv=5,
    scoring="accuracy"
)

grid_search.fit(X, y)

print("Best parameters:")
print(grid_search.best_params_)

print("Best cross-validation accuracy:")
print(grid_search.best_score_)
# Out:
# Best parameters:
# {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Best cross-validation accuracy:
# 0.9800000000000001

# %% [markdown]
# ### Question 3: Save the Trained Model using Joblib

# %%
import joblib

best_model = grid_search.best_estimator_

joblib.dump(best_model, "svm_model.pkl")

print("SVM model saved successfully.")
# Out:
# SVM model saved successfully.

# %% [markdown]
# ### Question 4: Load Model and Predict on New Data

# %%
loaded_model = joblib.load("svm_model.pkl")

new_data = X[:2]

predictions = loaded_model.predict(new_data)

print("Predictions on new data:")
print(predictions)
# Out:
# Predictions on new data:
# [0 0]
